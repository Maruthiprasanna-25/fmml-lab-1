# %% [markdown]
# <a href="https://colab.research.google.com/github/Maruthiprasanna-25/fmml-lab-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-04 14:49:24--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  85.3MB/s    in 0.8s
#
# 2024-05-04 14:49:26 (85.3 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 2421 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2171 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 96  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 6  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39234  1504.01502v1  We present an improved model and theory for ti...    cs
# 22642  1703.04864v2  We propose a data aggregation-based algorithm ...  stat
# 15092   1402.7265v1  Over the past 50 years many have debated what ...    cs
# 10587   1309.4844v1  We present five methods to the problem of netw...  stat
# 7333   1711.10353v1  The study of networks has witnessed an explosi...  stat
# ...             ...                                                ...   ...
# 7301   1711.08171v1  The graph Laplacian plays key roles in informa...  stat
# 9298    1102.5549v4  Technology has had an unquestionable impact on...  stat
# 23031  1802.04960v1  Suppose that one particular block in a stochas...  stat
# 5412    1104.4512v1  Notwithstanding the popularity of conventional...  stat
# 7539   1802.01765v1  We relate the minimax game of generative adver...    cs
#
#                                                    title  year  \
# 39234  Separable time-causal and time-recursive spati...  2015
# 22642  Optimization for L1-Norm Error Fitting via Dat...  2017
# 15092  Semantics, Modelling, and the Problem of Repre...  2014
# 10587  Network Anomaly Detection: A Survey and Compar...  2013
# 7333     Kernel-based Inference of Functions over Graphs  2017
# ...                                                  ...   ...
# 7301   Hypergraph $p$-Laplacian: A Differential Geome...  2017
# 9298   Instant Replay: Investigating statistical Anal...  2011
# 23031  Vertex nomination: The canonical sampling and ...  2018
# 5412   Robust Clustering Using Outlier-Sparsity Regul...  2011
# 7539   Training Generative Adversarial Networks via P...  2018
#
#                                                 keywords
# 39234  [present, improved, recursive, temporal, recep...
# 22642  [propose, aggregation, algorithm, monotonic, c...
# 15092  [debated, representation, capture, meaning, na...
# 10587  [present, methods, problem, network, anomaly, ...
# 7333   [networks, witnessed, explosive, decades, seve...
# ...                                                  ...
# 7301   [laplacian, information, processing, relationa...
# 9298   [technology, unquestionable, technological, ev...
# 23031  [suppose, particular, stochastic, interesting,...
# 5412   [notwithstanding, popularity, conventional, cl...
# 7539   [minimax, generative, adversarial, networks, f...
#
# [3673 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39234    [present, improved, recursive, temporal, recep...
# 22642    [propose, aggregation, algorithm, monotonic, c...
# 15092    [debated, representation, capture, meaning, na...
# 10587    [present, methods, problem, network, anomaly, ...
# 7333     [networks, witnessed, explosive, decades, seve...
#                                ...
# 17158    [segmentation, pivotal, improving, application...
# 37907    [consider, inverse, covariance, regularization...
# 17142    [attention, standard, component, machine, tran...
# 31776    [applications, require, optimizing, unknown, f...
# 19273    [complete, approach, reasoning, uncertainty, r...
# Name: keywords, Length: 4592, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 12022 words.
# Out of those 472 have over 96 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9a3663f5-90e4-41d1-b546-88f86fb5df1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a3663f5-90e4-41d1-b546-88f86fb5df1b")) {                    Plotly.newPlot(                        "9a3663f5-90e4-41d1-b546-88f86fb5df1b",                        [{"x":["presented","resulting","dynamics","implementation","gaussian","obtained","improved","discrete","compared","spatial","previous","specifically","temporal","combination","different","present","increasing","dimensional","generalized","algorithms","proposed","popular","problems","regression","computational","component","optimization","results","problem","constraints","studied","datasets","assumption","function","algorithm","propose","convergence","analysis","arbitrary","version","representation","research","literature","modelling","recently","natural","language","capture","representations","statistical","through","including","evaluate","simulated","individual","support","advantages","combining","techniques","stochastic","clustering","network","machines","detection","methods","reconstruction","dynamic","defined","related","examples","approaches","introduced","effective","presents","modeling","considered","numerical","framework","effectiveness","several","naturally","processing","networks","functions","particularly","inference","settings","scalable","sampling","available","address","conditions","accurate","selection","underlying","particular","structure","estimate","sensing","regularization","efficient","signals","samples","specific","produce","applications","because","moreover","possible","experiments","objective","procedure","descent","iterative","classes","knowledge","information","features","furthermore","understanding","training","unsupervised","between","semantic","contrast","performance","introduces","require","achieved","objects","recognition","learning","estimation","probabilistic","strategy","observations","likelihood","maximum","decision","outperform","variable","regularized","develop","optimal","prediction","variety","variables","enables","classifiers","introduce","predictions","perform","factors","requires","classification","classifier","existing","outperforms","processes","multiple","approach","behavior","supervised","process","strategies","structured","powerful","embedding","hierarchical","success","studies","demonstrate","empirical","patterns","predicting","typically","trained","without","recurrent","predictive","independent","identification","competitive","aspects","challenging","machine","functional","applied","usually","provides","estimated","parameters","application","clusters","standard","mixture","practical","unknown","developed","simultaneously"],"y":[129,103,40,117,78,158,116,56,248,96,217,131,116,91,520,493,83,127,52,411,669,95,327,80,186,81,231,844,646,106,54,352,54,276,574,754,92,382,66,58,250,202,75,38,176,211,244,100,153,115,266,160,169,50,85,127,62,75,248,96,102,550,43,254,592,72,106,85,131,101,294,105,175,138,143,96,66,388,138,306,49,222,514,142,52,162,47,51,66,202,151,82,127,118,71,154,265,75,42,52,277,53,115,182,79,299,114,88,154,420,119,85,45,54,94,252,494,380,125,116,414,112,463,172,93,574,63,95,124,126,276,887,133,126,101,61,49,67,142,66,66,31,132,159,160,91,95,84,65,228,48,160,53,101,358,100,311,188,84,254,681,58,126,263,74,73,66,75,75,72,101,389,110,97,57,83,194,208,119,43,100,60,78,55,190,279,30,182,70,163,37,192,165,33,204,47,90,44,136,73],"type":"bar"},{"x":["presented","resulting","dynamics","implementation","gaussian","obtained","improved","discrete","compared","spatial","previous","specifically","temporal","combination","different","present","increasing","dimensional","generalized","algorithms","proposed","popular","problems","reg ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (472,), (472, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7551686615886833

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experimental</span> <span style=''>Issues</span> <span style=''>in</span> <span style=''>Financial</span> <span style=''>Fraud</span> <span style='background-color:rgba(0, 255, 0, 0.4431818181818181);'>Detection</span> <span style=''>An</span> <span style=''>Investigation</span> <br/><br/><span style=''>Financial</span> <span style=''>fraud</span> <span style='background-color:rgba(0, 255, 0, 0.4431818181818181);'>detection</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>problem</span> <span style=''>with</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>design</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aspects</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consider</span> <span style=''>Issues</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analysis</span> <span style=''>will</span> <span style=''>affect</span> <span style=''>the</span> <span style=''>perceived</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ability</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>so</span> <span style=''>for</span> <span style=''>auditors</span> <span style=''>and</span> <span style=''>re</span> <span style=''>searchers</span> <span style=''>to</span> <span style=''>be</span> <span style=''>able</span> <span style=''>to</span> <span style=''>sufficiently</span> <span style=''>detect</span> <span style=''>financial</span> <span style=''>fraud</span> <span style=''>it</span> <span style=''>is</span> <span style=''>necessary</span> <span style=''>that</span> <span style=''>these</span> <span style=''>issues</span> <span style=''>be</span> <span style=''>thoroughly</span> <span style=''>explored</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>will</span> <span style=''>revisit</span> <span style=''>the</span> <span style=''>key</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>metrics</span> <span style=''>used</span> <span style=''>for</span> <span style=''>financial</span> <span style=''>fraud</span> <span style='background-color:rgba(0, 255, 0, 0.4431818181818181);'>detection</span> <span style=''>with</span> <span style=''>a</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>credit</span> <span style=''>card</span> <span style=''>fraud</span> <span style=''>critiquing</span> <span style=''>the</span> <span style=''>prevailing</span> <span style=''>ideas</span> <span style=''>and</span> <span style=''>offering</span> <span style=''>our</span> <span style=''>own</span> <span style=''>understandings</span> <span style=''>There</span> <span style=''>are</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>metrics</span> <span style=''>that</span> <span style=''>have</span> <span style=''>been</span> <span style=''>employed</span> <span style=''>in</span> <span style=''>prior</span> <span style=''>financial</span> <span style=''>fraud</span> <span style='background-color:rgba(0, 255, 0, 0.4431818181818181);'>detection</span> <span style='background-color:rgba(0, 255, 0, 0.3377483443708609);'>research</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Analysis</span> <span style=''>of</span> <span style=''>Objectives</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Fisher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <span style=''>in</span> <span style=''>Active</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Learning</span> <br/><br/><span style=''>Obtaining</span> <span style=''>labels</span> <span style=''>can</span> <span style=''>be</span> <span style=''>costly</span> <span style=''>and</span> <span style=''>time</span> <span style=''>consuming</span> <span style=''>Active</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learning</span> <span style=''>allows</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>intelligently</span> <span style=''>query</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>samples</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>labeled</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learning</span> <span style=''>Fisher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>ratio</span> <span style=''>(FIR)</span> <span style=''>has</span> <span style=''>been</span> <span style=''>used</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>for</span> <span style=''>selecting</span> <span style=''>queries</span> <span style=''>in</span> <span style=''>active</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>However</span> <span style=''>little</span> <span style=''>is</span> <span style=''>known</span> <span style=''>about</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>behind</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>FIR</span> <span style=''>for</span> <span style=''>active</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learning</span> <span style=''>There</span> <span style=''>is</span> <span style=''>a</span> <span style=''>gap</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>between</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>theory</span> <span style=''>and</span> <span style=''>the</span> <span style=''>motivation</span> <span style=''>of</span> <span style=''>its</span> <span style=''>usage</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practice</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>attempt</span> <span style=''>to</span> <span style=''>fill</span> <span style=''>this</span> <span style=''>gap</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>provide</span> <span style=''>a</span> <span style=''>rigorous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>analyzing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>existing</span> <span style=''>FIR</span> <span style=''>based</span> <span style=''>active</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methods</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Learning</span> <span style=''>Bounded</span> <span style=''>Treewidth</span> <span style='background-color:rgba(255, 0, 0, 0.42716049382716065);'>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Networks</span> <span style=''>with</span> <span style=''>Thousands</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.43452380952380953);'>Variables</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>present</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>learning</span> <span style=''>treewidth</span> <span style=''>bounded</span> <span style='background-color:rgba(255, 0, 0, 0.42716049382716065);'>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>networks</span> <span style=''>from</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>containing</span> <span style=''>thousands</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.43452380952380953);'>variables</span> <span style=''>Bounding</span> <span style=''>the</span> <span style=''>treewidth</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.42716049382716065);'>Bayesian</span> <span style=''>greatly</span> <span style=''>reduces</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>inferences</span> <span style=''>Yet</span> <span style=''>being</span> <span style=''>a</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>property</span> <span style=''>of</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>it</span> <span style=''>considerably</span> <span style=''>increases</span> <span style=''>the</span> <span style=''>difficulty</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>process</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>this</span> <span style=''>task</span> <span style=''>able</span> <span style=''>to</span> <span style=''>scale</span> <span style=''>to</span> <span style=''>large</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>domains</span> <span style=''>and</span> <span style=''>large</span> <span style=''>treewidths</span> <span style=''>Our</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approach</span> <span style=''>consistently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperforms</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>on</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>with</span> <span style=''>up</span> <span style=''>to</span> <span style=''>ten</span> <span style=''>thousand</span> <span style='background-color:rgba(255, 0, 0, 0.43452380952380953);'>variables</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>MinimalRNN</span> <span style=''>Toward</span> <span style=''>More</span> <span style=''>Interpretable</span> <span style=''>and</span> <span style=''>Trainable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Networks</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>MinimalRNN</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>achieves</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>popular</span> <span style=''>gated</span> <span style=''>RNNs</span> <span style=''>with</span> <span style=''>a</span> <span style=''>simplified</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>It</span> <span style=''>employs</span> <span style=''>minimal</span> <span style=''>updates</span> <span style=''>within</span> <span style=''>RNN</span> <span style=''>which</span> <span style=''>not</span> <span style=''>only</span> <span style=''>leads</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>testing</span> <span style=''>but</span> <span style=''>more</span> <span style=''>importantly</span> <span style=''>better</span> <span style=''>interpretability</span> <span style=''>and</span> <span style=''>trainability</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>by</span> <span style=''>endorsing</span> <span style=''>the</span> <span style=''>more</span> <span style=''>restrictive</span> <span style=''>update</span> <span style=''>rule</span> <span style=''>MinimalRNN</span> <span style=''>learns</span> <span style=''>disentangled</span> <span style=''>RNN</span> <span style=''>states</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>further</span> <span style=''>examine</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamics</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>RNN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>using</span> <span style=''>input</span> <span style=''>output</span> <span style=''>Jacobians</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>MinimalRNN</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>capture</span> <span style=''>longer</span> <span style=''>range</span> <span style=''>dependencies</span> <span style=''>than</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>existing</span> <span style=''>RNN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	information (0.25255623721881393)
# 	architecture (0.09713701431492842)
# 	systems (0.1467280163599182)
# 	detection (0.12985685071574643)
# 	different (0.2658486707566462)
# 	semantic (0.08793456032719836)
# 	convolutional (0.12832310838445807)
# 	language (0.12474437627811862)
# 	recognition (0.1411042944785276)
# 	network (0.28118609406952966)
#
# Some Statistics words are:
# 	algorithm (0.39778683750728017)
# 	bayesian (0.16831683168316833)
# 	theoretical (0.1607454863133372)
# 	distribution (0.19336051252184042)
# 	learning (0.5666860803727432)
# 	inference (0.20442632498543972)
# 	estimation (0.19219569015725102)
# 	dimensional (0.19219569015725102)
# 	gaussian (0.1729761211415259)
# 	regression (0.18171228887594643)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="20795d7a-4dab-488d-8cdb-967f8cad1c04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20795d7a-4dab-488d-8cdb-967f8cad1c04")) {                    Plotly.newPlot(                        "20795d7a-4dab-488d-8cdb-967f8cad1c04",                        [{"x":["presented","resulting","dynamics","implementation","gaussian","obtained","improved","discrete","compared","spatial","previous","specifically","temporal","combination","different","present","increasing","dimensional","generalized","algorithms","proposed","popular","problems","regression","computational","component","optimization","results","problem","constraints","studied","datasets","assumption","function","algorithm","propose","convergence","analysis","arbitrary","version","representation","research","literature","modelling","recently","natural","language","capture","representations","statistical","through","including","evaluate","simulated","individual","support","advantages","combining","techniques","stochastic","clustering","network","machines","detection","methods","reconstruction","dynamic","defined","related","examples","approaches","introduced","effective","presents","modeling","considered","numerical","framework","effectiveness","several","naturally","processing","networks","functions","particularly","inference","settings","scalable","sampling","available","address","conditions","accurate","selection","underlying","particular","structure","estimate","sensing","regularization","efficient","signals","samples","specific","produce","applications","because","moreover","possible","experiments","objective","procedure","descent","iterative","classes","knowledge","information","features","furthermore","understanding","training","unsupervised","between","semantic","contrast","performance","introduces","require","achieved","objects","recognition","learning","estimation","probabilistic","strategy","observations","likelihood","maximum","decision","outperform","variable","regularized","develop","optimal","prediction","variety","variables","enables","classifiers","introduce","predictions","perform","factors","requires","classification","classifier","existing","outperforms","processes","multiple","approach","behavior","supervised","process","strategies","structured","powerful","embedding","hierarchical","success","studies","demonstrate","empirical","patterns","predicting","typically","trained","without","recurrent","predictive","independent","identification","competitive","aspects","challenging","machine","functional","applied","usually","provides","estimated","parameters","application","clusters","standard","mixture","practical","unknown","developed","simultaneously","robustness","statistics","performs","performed","however","components","similarity","general","quality","similar","appropriate","reduction","dimensionality","difficult","formulation","structures","describe","evaluation","provide","distance","solving","distributed","technique","constraint","solution","posterior","required","simulation","expected","computing","bayesian","development","certain","computationally","significant","performing","reasoning","instead","context","automated","provided","theoretical","special","classical","identify","average","analyze","another","variance","product","improving","improvement","generation","experimental","further","overall","question","probability","practice","fundamental","critical","structural","weighted","establish","accuracy","imaging","efficiency","continuous","traditional","explore","estimator","directly","interest","properties","alternative","showing","designed","estimating","setting","consider","construct","dimension","parameter","adaptive","sparsity","segmentation", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
#
# Some words which never appear in Statistics papers:

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 0.007425461965763518

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7562568008705114
