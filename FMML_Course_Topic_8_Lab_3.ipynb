# %% [markdown]
# <a href="https://colab.research.google.com/github/Maruthiprasanna-25/fmml-lab-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-21 15:22:26--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   117MB/s    in 0.6s
#
# 2024-04-21 15:22:28 (117 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22099   1411.2540v2  This paper considers statistical estimation pr...  stat
# 7398   1712.04688v1  In variable or graph selection problems, findi...  stat
# 21643   1209.5375v2  Typical cohorts in brain imaging studies are n...  stat
# 1681   1803.07133v1  This paper presents a systematic survey on rec...    cs
# 1553   1609.08144v2  Neural Machine Translation (NMT) is an end-to-...    cs
# ...             ...                                                ...   ...
# 5162    1011.5395v1  A large set of signals can sometimes be descri...  stat
# 5606    1309.6834v1  This paper considers the problem of learning t...    cs
# 26295  1609.07306v1  Marker-based and marker-less optical skeletal ...    cs
# 21113  1708.01791v1  The multi-armed bandit problem forms the found...    cs
# 37884   1012.5066v2  We consider adaptive system identification pro...  stat
#
#                                                    title  year  \
# 22099  Parameter estimation in spherical symmetry groups  2014
# 7398   Stability Selection for Structured Variable Se...  2017
# 21643  Improving accuracy and power with transfer lea...  2012
# 1681    Neural Text Generation: Past, Present and Beyond  2018
# 1553   Google's Neural Machine Translation System: Br...  2016
# ...                                                  ...   ...
# 5162        The Sample Complexity of Dictionary Learning  2010
# 5606   Unsupervised Learning of Noisy-Or Bayesian Net...  2013
# 26295  EgoCap: Egocentric Marker-less Motion Capture ...  2016
# 21113  Thompson Sampling Guided Stochastic Searching ...  2017
# 37884           Regularized Least-Mean-Square Algorithms  2010
#
#                                                 keywords
# 22099  [considers, statistical, estimation, probabili...
# 7398   [selection, controlling, positives, notoriousl...
# 21643  [systematic, information, contained, hypothese...
# 1681   [systematic, development, generation, specific...
# 1553   [translation, automated, translation, potentia...
# ...                                                  ...
# 5162   [sometimes, described, dictionary, represented...
# 5606   [considers, parameters, variables, structure, ...
# 26295  [arrangement, viewpoints, converging, discomfo...
# 21113  [foundation, stochastic, optimization, effecti...
# 37884  [identification, constraints, regularized, alg...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22099    [considers, statistical, estimation, probabili...
# 7398     [selection, controlling, positives, notoriousl...
# 21643    [systematic, information, contained, hypothese...
# 1681     [systematic, development, generation, specific...
# 1553     [translation, automated, translation, potentia...
#                                ...
# 21533    [increasing, motivated, frameworks, multitask,...
# 7053     [estimation, dirichlet, distributed, environme...
# 35962    [acknowledged, benchmark, programming, communi...
# 24804    [estimation, egocentric, viewpoints, particula...
# 34625    [highlight, important, algorithmic, disparity,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8810 words.
# Out of those 4586 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e55aaab6-2b82-419f-a573-4993472a758d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e55aaab6-2b82-419f-a573-4993472a758d")) {                    Plotly.newPlot(                        "e55aaab6-2b82-419f-a573-4993472a758d",                        [{"x":["spherical","considers","illustrated","microscopy","associated","representation","concentration","establish","advantages","parameter","extension","respectively","statistical","distributions","diffraction","estimator","estimation","simulations","distribution","restricted","parameterized","algorithm","maximization","symmetric","experiments","topological","estimated","parameters","orientation","likelihood","invariant","specialized","expectation","probability","applicability","structured","strengths","notoriously","orthogonal","demonstrated","difficult","increases","guidelines","conjunction","algorithms","strategies","controlling","stability","highlight","validation","weaknesses","reliability","investigate","competing","structure","selection","positives","procedure","predictive","specification","principled","biomarkers","hypotheses","formalized","functional","demonstrate","facilitate","involving","coordinates","improving","situation","discriminant","investigators","detection","sometimes","potential","locations","previously","systematic","prediction","conditions","reference","experimental","different","contained","information","generative","techniques","properties","benchmarking","specifically","reinforcement","adversarial","diversity","corresponding","parametrization","aforementioned","empirical","traditional","shortcoming","vanishing","experiment","recurrent","introduce","development","generation","competitive","sentences","translation","arithmetic","efficiency","benchmarks","connections","character","expensive","therefore","flexibility","conventional","parallelism","ultimately","unfortunately","computationally","essential","attention","mechanism","production","difficulty","delimited","precision","automated","inference","naturally","normalization","computations","accelerate","encourages","technique","practical","evaluation","deployments","automatic","comprehensive","treatments","performance","healthcare","unlabeled","covariates","treatment","censoring","estimating","assignments","available","predictions","questions","challenging","established","framework","including","important","misspecified","numerical","expressed","integrand","convergence","consistent","quadrature","assumption","integrands","dimensional","guarantees","contribution","statistics","alternatives","smoothness","reproducing","integration","benchmark","implementation","sufficient","operators","multipliers","multiplications","approximately","circumvents","approximating","processes","posterior","stochastic","parametric","variational","quantifying","regression","effectiveness","construction","seemingly","interested","introduces","uncertainty","simulated","contradictory"],"y":[7,40,16,11,102,385,8,54,91,114,71,87,133,110,2,25,220,52,200,40,24,811,34,17,593,21,75,251,29,64,67,28,31,167,41,105,22,5,11,98,160,62,9,29,568,107,15,35,30,53,18,27,122,27,348,149,12,120,57,15,26,3,31,10,44,569,44,51,13,108,33,16,0,321,21,159,51,94,30,237,137,59,406,733,23,705,124,370,206,11,155,126,113,50,136,5,13,183,167,6,15,70,162,347,130,159,97,56,126,10,164,112,49,54,76,145,34,103,9,11,37,112,63,179,111,22,47,2,77,115,216,55,25,30,18,11,260,142,257,2,207,62,5,892,8,42,1,29,1,64,15,296,95,72,298,65,544,236,346,0,86,22,1,111,75,2,55,0,162,59,64,65,19,17,13,42,221,146,68,46,14,6,32,1,14,110,49,126,47,52,10,131,200,65,4,30,89,81,53,6],"type":"bar"},{"x":["spherical","considers","illustrated","microscopy","associated","representation","c ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4586,), (4586, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Indexing</span> <span style=''>the</span> <span style=''>Event</span> <span style=''>Calculus</span> <span style=''>with</span> <span style=''>Kd</span> <span style=''>trees</span> <span style=''>to</span> <span style=''>Monitor</span> <span style=''>Diabetes</span> <br/><br/><span style=''>Personal</span> <span style=''>Health</span> <span style=''>Systems</span> <span style=''>(PHS)</span> <span style=''>are</span> <span style=''>mobile</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>tailored</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>monitoring</span> <span style=''>patients</span> <span style=''>affected</span> <span style=''>by</span> <span style=''>chronic</span> <span style=''>non</span> <span style=''>communicable</span> <span style=''>diseases</span> <span style=''>A</span> <span style=''>patient</span> <span style=''>affected</span> <span style=''>by</span> <span style=''>a</span> <span style=''>chronic</span> <span style=''>disease</span> <span style=''>can</span> <span style=''>generate</span> <span style=''>large</span> <span style=''>amounts</span> <span style=''>of</span> <span style=''>events</span> <span style=''>Type</span> <span style=''>1</span> <span style=''>Diabetic</span> <span style=''>patients</span> <span style=''>generate</span> <span style=''>several</span> <span style=''>glucose</span> <span style=''>events</span> <span style=''>per</span> <span style=''>day</span> <span style=''>ranging</span> <span style=''>from</span> <span style=''>at</span> <span style=''>least</span> <span style=''>6</span> <span style=''>events</span> <span style=''>per</span> <span style=''>day</span> <span style=''>(under</span> <span style=''>normal</span> <span style=''>monitoring)</span> <span style=''>to</span> <span style=''>288</span> <span style=''>per</span> <span style=''>day</span> <span style=''>when</span> <span style=''>wearing</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>glucose</span> <span style=''>monitor</span> <span style=''>(CGM)</span> <span style=''>that</span> <span style=''>samples</span> <span style=''>the</span> <span style=''>blood</span> <span style=''>every</span> <span style=''>5</span> <span style=''>minutes</span> <span style=''>for</span> <span style=''>several</span> <span style=''>days</span> <span style=''>This</span> <span style=''>is</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>events</span> <span style=''>to</span> <span style=''>monitor</span> <span style=''>for</span> <span style=''>medical</span> <span style=''>doctors</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>when</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considering</span> <span style=''>that</span> <span style=''>they</span> <span style=''>may</span> <span style=''>have</span> <span style=''>to</span> <span style=''>take</span> <span style='background-color:rgba(0, 255, 0, 0.4022988505747126);'>decisions</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>concerning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adjusting</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>treatment</span> <span style=''>which</span> <span style=''>may</span> <span style=''>impact</span> <span style=''>the</span> <span style=''>life</span> <span style=''>of</span> <span style=''>the</span> <span style=''>patients</span> <span style=''>for</span> <span style=''>a</span> <span style=''>long</span> <span style=''>time</span> <span style=''>Given</span> <span style=''>the</span> <span style=''>need</span> <span style=''>to</span> <span style=''>analyse</span> <span style=''>such</span> <span style=''>a</span> <span style=''>large</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Latent</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>Latent</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>which</span> <span style=''>is</span> <span style=''>a</span> <span style=''>latent</span> <span style=''>variable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>allowing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>of</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style=''>multi</span> <span style=''>modal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>using</span> <span style=''>GPs</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>built</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extending</span> <span style=''>the</span> <span style=''>input</span> <span style=''>space</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>a</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>that</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>modulate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>function</span> <span style=''>over</span> <span style=''>the</span> <span style=''>training</span> <span style=''>data</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>model</span> <span style=''>multi</span> <span style=''>modal</span> <span style=''>and</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exemplify</span> <span style=''>the</span> <span style=''>approach</span> <span style=''>on</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>data</span> <span style=''>and</span> <span style=''>provide</span> <span style=''>results</span> <span style=''>on</span> <span style=''>real</span> <span style=''>data</span> <span style=''>from</span> <span style=''>motion</span> <span style=''>capture</span> <span style=''>and</span> <span style=''>geostatistics</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>GroupLiNGAM</span> <span style=''>Linear</span> <span style=''>non</span> <span style=''>Gaussian</span> <span style=''>acyclic</span> <span style=''>models</span> <span style=''>for</span> <span style=''>sets</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.407766990291262);'>variables</span> <br/><br/><span style=''>Finding</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3121019108280254);'>graphical</span> <span style=''>model</span> <span style=''>has</span> <span style=''>been</span> <span style=''>received</span> <span style=''>much</span> <span style='background-color:rgba(0, 255, 0, 0.3984375000000001);'>attention</span> <span style=''>in</span> <span style=''>many</span> <span style=''>fields</span> <span style=''>Recently</span> <span style=''>it</span> <span style=''>is</span> <span style=''>reported</span> <span style=''>that</span> <span style=''>the</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>Gaussianity</span> <span style=''>of</span> <span style=''>data</span> <span style=''>enables</span> <span style=''>us</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>a</span> <span style=''>directed</span> <span style=''>acyclic</span> <span style=''>graph</span> <span style=''>without</span> <span style=''>any</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.39463601532567055);'>knowledge</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>Gaussianity</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>more</span> <span style=''>general</span> <span style=''>type</span> <span style=''>of</span> <span style=''>models</span> <span style=''>chain</span> <span style=''>graphs</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>finds</span> <span style=''>an</span> <span style=''>ordering</span> <span style=''>of</span> <span style=''>the</span> <span style=''>disjoint</span> <span style=''>subsets</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.407766990291262);'>variables</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteratively</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923076);'>evaluating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independence</span> <span style=''>between</span> <span style=''>the</span> <span style=''>variable</span> <span style=''>subset</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5999999999999999);'>residuals</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>remaining</span> <span style='background-color:rgba(255, 0, 0, 0.407766990291262);'>variables</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regressed</span> <span style=''>on</span> <span style=''>those</span> <span style=''>However</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>grows</span> <span style='backgro ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Time</span> <span style=''>series</span> <span style=''>modeling</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>approach</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>latent</span> <span style=''>process</span> <br/><br/><span style=''>Time</span> <span style=''>series</span> <span style=''>are</span> <span style=''>used</span> <span style=''>in</span> <span style=''>many</span> <span style=''>domains</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>finance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>economics</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bioinformatics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>the</span> <span style=''>change</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurement</span> <span style=''>over</span> <span style=''>time</span> <span style=''>Modeling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>may</span> <span style=''>then</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>give</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style=''>such</span> <span style=''>data</span> <span style=''>A</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>time</span> <span style=''>series</span> <span style=''>modeling</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>It</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporating</span> <span style=''>a</span> <span style=''>discrete</span> <span style=''>hidden</span> <span style=''>logistic</span> <span style=''>process</span> <span style=''>allowing</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activating</span> <span style=''>smoothly</span> <span style=''>or</span> <span style=''>abruptly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>models</span> <span style=''>The</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>by</span> <span style=''>the</span> <span style=''>maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dedicated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Maximization</span> <span style=''>(EM)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>The</span> <span style=''>M</span> <span style=''>step</span> <span style=''>of</span> <span style=''>the</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12972202423378476)
# 	segmentation (0.06949394155381326)
# 	challenging (0.10620099786172488)
# 	experimental (0.14468995010691377)
# 	representation (0.13720598717034926)
# 	detection (0.11439771917320028)
# 	information (0.2512473271560941)
# 	different (0.26122594440484675)
# 	convolutional (0.13257305773342837)
# 	recognition (0.13435495367070563)
#
# Some Statistics words are:
# 	stochastic (0.1283851554663992)
# 	estimation (0.1720160481444333)
# 	statistical (0.14343029087261785)
# 	variables (0.14543630892678033)
# 	theoretical (0.15245737211634905)
# 	algorithm (0.3946840521564694)
# 	distribution (0.18455366098294884)
# 	inference (0.19408224674022065)
# 	dimensional (0.18655967903711135)
# 	regression (0.18355065195586762)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6c54600a-7466-40c6-9c32-2b5f085d52d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c54600a-7466-40c6-9c32-2b5f085d52d6")) {                    Plotly.newPlot(                        "6c54600a-7466-40c6-9c32-2b5f085d52d6",                        [{"x":["spherical","considers","illustrated","microscopy","associated","representation","concentration","establish","advantages","parameter","extension","respectively","statistical","distributions","diffraction","estimator","estimation","simulations","distribution","restricted","parameterized","algorithm","maximization","symmetric","experiments","topological","estimated","parameters","orientation","likelihood","invariant","specialized","expectation","probability","applicability","structured","strengths","notoriously","orthogonal","demonstrated","difficult","increases","guidelines","conjunction","algorithms","strategies","controlling","stability","highlight","validation","weaknesses","reliability","investigate","competing","structure","selection","positives","procedure","predictive","specification","principled","biomarkers","hypotheses","formalized","functional","demonstrate","facilitate","involving","coordinates","improving","situation","discriminant","investigators","detection","sometimes","potential","locations","previously","systematic","prediction","conditions","reference","experimental","different","contained","information","generative","techniques","properties","benchmarking","specifically","reinforcement","adversarial","diversity","corresponding","parametrization","aforementioned","empirical","traditional","shortcoming","vanishing","experiment","recurrent","introduce","development","generation","competitive","sentences","translation","arithmetic","efficiency","benchmarks","connections","character","expensive","therefore","flexibility","conventional","parallelism","ultimately","unfortunately","computationally","essential","attention","mechanism","production","difficulty","delimited","precision","automated","inference","naturally","normalization","computations","accelerate","encourages","technique","practical","evaluation","deployments","automatic","comprehensive","treatments","performance","healthcare","unlabeled","covariates","treatment","censoring","estimating","assignments","available","predictions","questions","challenging","established","framework","including","important","misspecified","numerical","expressed","integrand","convergence","consistent","quadrature","assumption","integrands","dimensional","guarantees","contribution","statistics","alternatives","smoothness","reproducing","integration","benchmark","implementation","sufficient","operators","multipliers","multiplications","approximately","circumvents","approximating","processes","posterior","stochastic","parametric","variational","quantifying","regression","effectiveness","construction","seemingly","interested","introduces","uncertainty","simulated","contradictory","methodology","illustrative","conditional","undirected","graphical","resolution","applications","significant","citations","integrated","conditionally","coreference","partitioning","extraction","reduction","describes","extracted","circumvent","efficient","restrictions","conformal","description","confidence","constructing","assumptions","specified","regarding","comparative","personalized","incorporate","recommendation","precisely","filtering","recommendations","approaches","collaborative","movielens","incorporating","evaluated","construct","individuals","especially","implications","literature","presenting","technical","interpret","clustering","theoretical","accessible","arguments","selecting","shrinkage","scenarios","establishing","deterministic", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	investigators
# 	misspecified
# 	integrands
# 	conformal
# 	standardizing
# 	metabolic
# 	transports
# 	terabytes
# 	methodologically
# 	linearities
# 	normality
# 	incrementalonline
# 	collinearity
# 	corollary
# 	confounders
# 	exoplanet
# 	confounder
# 	radiological
# 	tradition
# 	unnecessarily
# Some words which never appear in Statistics papers:
# 	delimited
# 	citations
# 	coreference
# 	recompute
# 	superpixel
# 	cooperation
# 	navigation
# 	discarded
# 	modifiers
# 	extractions
# 	numbering
# 	commonsense
# 	judgments
# 	immunology
# 	eigenface
# 	illumination
# 	experimented
# 	eigenfaces
# 	occlusions
# 	cartesian

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0631624088709183e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7758333333333334
