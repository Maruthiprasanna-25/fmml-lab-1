# %% [markdown]
# <a href="https://colab.research.google.com/github/Maruthiprasanna-25/fmml-lab-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-04 10:19:42--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   110MB/s    in 0.6s
#
# 2024-04-04 10:19:44 (110 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 23157   0805.2690v1  Methods of increasing linear optical dynamic r...    cs
# 24892   1412.6124v1  In this paper, we study the problem of semanti...    cs
# 30876  1801.07455v2  Dynamics of human body skeletons convey signif...    cs
# 23132  cs/0609165v1  A simple search method for finding a blur conv...    cs
# 20906  1705.02175v1  Logic-based event recognition systems infer oc...    cs
# ...             ...                                                ...   ...
# 35335  cs/0406055v1  It is now well-admitted that formal methods ar...    cs
# 7585   1802.04198v1  The workflow of data scientists normally invol...  stat
# 13897  1605.01514v1  This paper concerns applications of genetic al...    cs
# 34093   1302.5675v1  Developing Question Answering systems has been...    cs
# 3171   1604.02917v2  We present a novel approach for supervised dom...  stat
#
#                                                    title  year  \
# 23157  Increasing Linear Dynamic Range of Commercial ...  2008
# 24892  Semantic Part Segmentation using Compositional...  2014
# 30876  Spatial Temporal Graph Convolutional Networks ...  2018
# 23132  Simple method to eliminate blur based on Lane ...  2006
# 20906   Distributed Online Learning of Event Definitions  2017
# ...                                                  ...   ...
# 35335           Web Services: A Process Algebra Approach  2004
# 7585   client2vec: Towards Systematic Baselines for B...  2018
# 13897  Fitness-based Adaptive Control of Parameters i...  2016
# 34093  Development of Yes/No Arabic Question Answerin...  2013
# 3171   Gaussian Process Domain Experts for Model Adap...  2016
#
#                                                 keywords
# 23157  [increasing, commercial, photocamera, describe...
# 24892  [segmentation, challenging, detection, segment...
# 30876  [skeletons, significant, information, recognit...
# 23132  [convolved, presented, experimentally, elimina...
# 20906  [recognition, occurrences, definitions, recogn...
# ...                                                  ...
# 35335  [framework, verification, specifications, exec...
# 7585   [scientists, potentially, inefficient, process...
# 13897  [applications, algorithms, programming, diffic...
# 34093  [developing, answering, important, disciplines...
# 3171   [supervised, adaptation, probabilistic, framew...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 23157    [increasing, commercial, photocamera, describe...
# 24892    [segmentation, challenging, detection, segment...
# 30876    [skeletons, significant, information, recognit...
# 23132    [convolved, presented, experimentally, elimina...
# 20906    [recognition, occurrences, definitions, recogn...
#                                ...
# 34608    [solutions, vocabulary, information, retrieval...
# 6863     [presented, convolutional, framework, introduc...
# 28809    [egocentric, throughout, manuscript, egocentri...
# 36280    [potential, decentralised, partially, observab...
# 12403    [represent, including, processing, important, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8688 words.
# Out of those 4573 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="89f0dcf5-7bab-4f91-90a5-90125fbc86db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89f0dcf5-7bab-4f91-90a5-90125fbc86db")) {                    Plotly.newPlot(                        "89f0dcf5-7bab-4f91-90a5-90125fbc86db",                        [{"x":["experimental","measurements","increasing","commercial","described","estimation","annotated","challenging","boundaries","demonstrate","viewpoints","challenges","inference","efficient","furthermore","annotation","appearance","combining","detection","complexity","effectiveness","segmentation","represent","incorporate","compositional","algorithm","programming","pixelwise","resulting","generalization","formulation","significant","convolutional","automatically","improvements","difficulties","capability","recognition","approaches","limitations","expressive","mainstream","information","skeletons","substantial","traversal","conventional","experimentally","convolved","presented","eliminate","providing","connections","distributed","processing","occurrences","benchmark","definitions","exchanging","applications","inductive","significantly","comprehensive","desiderata","incorporated","performers","classification","comparative","uniformity","evaluation","algorithms","including","characteristics","hierarchical","spatiotemporal","plausible","compression","potential","desirable","subsequent","conclusive","aggregation","understanding","superpixels","parsimony","annotations","appropriate","streaming","superpixel","validation","prediction","component","averaging","conditions","investigate","estimator","establish","partitions","underlying","computational","assumptions","computing","approximation","statistical","partition","separating","regression","advantages","partitioning","modification","management","considerations","originally","contrasting","available","preference","advantage","methodological","functions","application","particular","experiments","uncertainty","development","diagnosis","incorporating","distributional","inability","developed","axiomatic","specified","likelihood","intervals","principle","considered","predictions","accounted","quantification","capturing","conducted","assumption","technique","ensembled","quantifying","outperform","generation","distribution","optimization","introduce","formalize","modifying","maintained","convergence","performance","probabilistically","parameters","constraint","manipulator","probabilistic","syntactic","regularity","sentences","competing","practically","parsimonious","traditional","independent","structure","hypothesis","alternative","languages","crossings","dependency","dependencies","explanations","characterizes","capabilities","identification","depending","procedure","correctness","instruments","methodology","precisely","corresponding","intervention","automatic","interventions","injection","procedures","acquisition","navigation","identifies","improving","sequences","classical","processes","conditional","computationally","different"],"y":[388,59,95,24,71,220,63,245,34,539,12,121,199,416,183,62,71,98,345,214,203,195,101,74,26,804,123,5,146,138,54,237,397,176,114,27,53,365,398,59,26,2,690,2,46,3,106,49,3,180,14,103,52,114,305,14,207,25,3,396,19,250,58,2,29,3,511,42,2,283,604,237,76,99,16,26,61,157,33,24,3,32,158,7,3,69,74,12,5,46,232,98,25,130,156,21,47,7,113,283,60,150,140,153,28,12,138,86,17,28,51,8,11,9,317,24,93,7,221,248,282,580,75,114,37,67,25,5,189,3,27,57,11,62,129,94,2,11,49,75,61,244,0,12,79,135,228,296,344,13,16,6,119,893,3,265,94,3,173,41,9,77,26,13,7,179,136,297,41,99,100,2,43,50,20,13,43,95,25,111,18,5,58,35,135,12,180,6,3,30,44,28,16,112,112,112,108,96,84,787],"type":"bar"},{"x":["experimental","measurements","increasing","com ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4573,), (4573, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8175

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Leveraging</span> <span style=''>Network</span> <span style=''>Dynamics</span> <span style=''>for</span> <span style=''>Improved</span> <span style=''>Link</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <br/><br/><span style=''>The</span> <span style=''>aim</span> <span style=''>of</span> <span style=''>link</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>is</span> <span style=''>to</span> <span style=''>forecast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connections</span> <span style=''>that</span> <span style=''>are</span> <span style=''>most</span> <span style=''>likely</span> <span style=''>to</span> <span style=''>occur</span> <span style=''>in</span> <span style=''>the</span> <span style=''>future</span> <span style=''>based</span> <span style=''>on</span> <span style=''>examples</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>previously</span> <span style=''>observed</span> <span style=''>links</span> <span style=''>A</span> <span style=''>key</span> <span style=''>insight</span> <span style=''>is</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>useful</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explicitly</span> <span style=''>model</span> <span style=''>network</span> <span style=''>dynamics</span> <span style=''>how</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>frequently</span> <span style=''>links</span> <span style=''>are</span> <span style=''>created</span> <span style=''>or</span> <span style=''>destroyed</span> <span style=''>when</span> <span style=''>doing</span> <span style=''>link</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>link</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>RPM</span> <span style=''>(Rate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <span style=''>Model)</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarity</span> <span style=''>measures</span> <span style=''>RPM</span> <span style=''>uses</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicted</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>link</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modifications</span> <span style=''>modeled</span> <span style=''>using</span> <span style=''>time</span> <span style=''>series</span> <span style=''>data</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.4676258992805755);'>implemented</span> <span style=''>in</span> <span style=''>Spark</span> <span style=''>ML</span> <span style=''>and</span> <span style=''>trained</span> <span style=''>with</span> <span style=''>the</span> <span style=''>original</span> <span style=''>link</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>a</span> <span style=''>small</span> <span style=''>balanced</span> <span style=''>subset</span> <span style=''>We</span> <span style=''>compare</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>this</span> <span style=''>network</span> <span style=''>dynami ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>for</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>armed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contextual</span> <span style=''>bandit</span> <br/><br/><span style=''>In</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>biomedical</span> <span style=''>science</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineering</span> <span style=''>problems</span> <span style=''>one</span> <span style=''>must</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequentially</span> <span style=''>decide</span> <span style=''>which</span> <span style=''>action</span> <span style=''>to</span> <span style=''>take</span> <span style=''>next</span> <span style=''>so</span> <span style=''>as</span> <span style=''>to</span> <span style=''>maximize</span> <span style=''>rewards</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reinforcement</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>an</span> <span style=''>area</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>that</span> <span style=''>studies</span> <span style=''>how</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximization</span> <span style=''>balances</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploration</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploitation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>with</span> <span style=''>the</span> <span style=''>world</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>learning</span> <span style=''>how</span> <span style=''>the</span> <span style=''>world</span> <span style=''>operates</span> <span style=''>One</span> <span style=''>general</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>this</span> <span style=''>type</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>setting</span> <span style=''>and</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contextual</span> <span style=''>bandit</span> <span style=''>case</span> <span style=''>in</span> <span style=''>which</span> <span style=''>observed</span> <span style=''>rewards</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>on</span> <span style=''>each</span> <span style=''>action</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>on</span> <span style=''>given</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>or</span> <span style=''>context</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>at</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>with</span> <span style=''>the</span> <span style=''>world</span> <span style=''>The</span> <span style=''>Thompson</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>has</span> <span style=''>recently</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structured</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <span style=''>Theory</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Calibrated</span> <span style=''>Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Surrogate</span> <span style=''>Losses</span> <br/><br/><span style=''>We</span> <span style=''>provide</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3090128755364807);'>theoretical</span> <span style=''>insights</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surrogate</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.37579617834394907);'>minimization</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>For</span> <span style=''>any</span> <span style=''>task</span> <span style=''>loss</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surrogate</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimized</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.304812834224599);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>and</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>tight</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>so</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923076);'>calibration</span> <span style=''>function</span> <span style=''>relating</span> <span style=''>the</span> <span style=''>excess</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surrogate</span> <span style=''>risk</span> <span style=''>to</span> <span style=''>the</span> <span style=''>actual</span> <span style=''>risk</span> <span style=''>In</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>prior</span> <span style=''>related</span> <span style=''>work</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>carefully</span> <span style=''>monitor</span> <span style=''>the</span> <span style=''>effect</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>number</span> <span style=''>of</span> <span style=''>classes</span> <span style=''>in</span> <span style=''>the</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>As</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interesting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consequence</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.30000000000000004);'>formalize</span> <span style=''>the</span> <span style='background-color:rgba(0, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Bootstrapping</span> <span style=''>Graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>for</span> <span style=''>Autism</span> <span style=''>Spectrum</span> <span style=''>Disorder</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <br/><br/><span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>models</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>patterns</span> <span style=''>that</span> <span style=''>can</span> <span style=''>act</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biomarkers</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>neuropathoglogical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>is</span> <span style=''>becoming</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prevalent</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>Autism</span> <span style=''>Spectrum</span> <span style=''>Disorder</span> <span style=''>(ASD)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>While</span> <span style=''>non</span> <span style=''>invasive</span> <span style=''>imaging</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>rest</span> <span style=''>state</span> <span style=''>fMRI</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>used</span> <span style=''>in</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>beneficial</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>non</span> <span style=''>imaging</span> <span style=''>features</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>personal</span> <span style=''>and</span> <span style=''>socio</span> <span style=''>cultural</span> <span style=''>traits</span> <span style=''>into</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>modeling</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>employ</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combining</span> <span style=''>both</span> <span style=''>types</span> <span style=''>of</span> <span style=''>feature</span> <span style=''>where</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contextual</span> <span style=''>graph</span> <span style=''>encodes</span> <span style=''>the</span> <span style=''>traits</span> <span style=''>of</span> <span style=''>a</span> <span style=''>larger</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>population</span> <span style=''>while</span> <span style=''>the</span> <span style=''>brain</span> <span style=''>activity</span> <span style=''>patterns</span> <span style=''>are</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>a</span> <spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.10165229885057471)
# 	processing (0.10955459770114942)
# 	experimental (0.13936781609195403)
# 	segmentation (0.07004310344827586)
# 	architecture (0.0951867816091954)
# 	information (0.2478448275862069)
# 	detection (0.12392241379310345)
# 	different (0.2826867816091954)
# 	recognition (0.13110632183908047)
# 	convolutional (0.14260057471264367)
#
# Some Statistics words are:
# 	estimation (0.15873015873015872)
# 	variational (0.09871031746031746)
# 	variables (0.13194444444444445)
# 	algorithm (0.3814484126984127)
# 	theoretical (0.15128968253968253)
# 	statistical (0.15625)
# 	distribution (0.18452380952380953)
# 	dimensional (0.18551587301587302)
# 	inference (0.1984126984126984)
# 	regression (0.18154761904761904)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a3e00ac5-8fdf-47a9-b1f3-11c9352ad393" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3e00ac5-8fdf-47a9-b1f3-11c9352ad393")) {                    Plotly.newPlot(                        "a3e00ac5-8fdf-47a9-b1f3-11c9352ad393",                        [{"x":["experimental","measurements","increasing","commercial","described","estimation","annotated","challenging","boundaries","demonstrate","viewpoints","challenges","inference","efficient","furthermore","annotation","appearance","combining","detection","complexity","effectiveness","segmentation","represent","incorporate","compositional","algorithm","programming","pixelwise","resulting","generalization","formulation","significant","convolutional","automatically","improvements","difficulties","capability","recognition","approaches","limitations","expressive","mainstream","information","skeletons","substantial","traversal","conventional","experimentally","convolved","presented","eliminate","providing","connections","distributed","processing","occurrences","benchmark","definitions","exchanging","applications","inductive","significantly","comprehensive","desiderata","incorporated","performers","classification","comparative","uniformity","evaluation","algorithms","including","characteristics","hierarchical","spatiotemporal","plausible","compression","potential","desirable","subsequent","conclusive","aggregation","understanding","superpixels","parsimony","annotations","appropriate","streaming","superpixel","validation","prediction","component","averaging","conditions","investigate","estimator","establish","partitions","underlying","computational","assumptions","computing","approximation","statistical","partition","separating","regression","advantages","partitioning","modification","management","considerations","originally","contrasting","available","preference","advantage","methodological","functions","application","particular","experiments","uncertainty","development","diagnosis","incorporating","distributional","inability","developed","axiomatic","specified","likelihood","intervals","principle","considered","predictions","accounted","quantification","capturing","conducted","assumption","technique","ensembled","quantifying","outperform","generation","distribution","optimization","introduce","formalize","modifying","maintained","convergence","performance","probabilistically","parameters","constraint","manipulator","probabilistic","syntactic","regularity","sentences","competing","practically","parsimonious","traditional","independent","structure","hypothesis","alternative","languages","crossings","dependency","dependencies","explanations","characterizes","capabilities","identification","depending","procedure","correctness","instruments","methodology","precisely","corresponding","intervention","automatic","interventions","injection","procedures","acquisition","navigation","identifies","improving","sequences","classical","processes","conditional","computationally","different","feasibility","performed","mentioned","abduction","refinement","effective","framework","incomplete","execution","performances","assessment","nonetheless","incompleteness","diffusion","executions","empirical","distributions","estimators","existence","evaluations","shrinkage","consideration","statistics","principal","reproducing","theoretical","phenomenon","important","embedding","inferences","sufficient","overfitting","generalized","condition","detecting","techniques","adversary","precision","individual","membership","fundamental","necessary","protecting","influences","discovers","determines","instances","overfitted","selecting","vulnerable","specifically","understood","successfully","indirectly","interaction"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	ensembled
# 	econometrics
# 	asymptotics
# 	unsuccessful
# 	idealized
# 	heteroskedastic
# 	distributedly
# 	reweighted
# 	centering
# 	recidivism
# 	repeating
# 	biophysical
# 	counterexample
# 	changepoint
# 	changepoints
# 	depressive
# 	anopheles
# 	refitting
# 	circumvents
# 	amortization
# Some words which never appear in Statistics papers:
# 	skeletons
# 	traversal
# 	exchanging
# 	performers
# 	superpixel
# 	manipulator
# 	abduction
# 	incompleteness
# 	executions
# 	volumetric
# 	avoidance
# 	obstacles
# 	surpassed
# 	untrimmed
# 	pervasive
# 	admissible
# 	dialectal
# 	evolvable
# 	precomputed
# 	acoustically

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.085181871471323e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.76
