# %% [markdown]
# <a href="https://colab.research.google.com/github/Maruthiprasanna-25/fmml-lab-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-20 15:44:41--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   104MB/s    in 0.7s
#
# 2024-05-20 15:44:43 (104 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3111 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2618 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 32  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 7  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 13817  1507.02835v1  Random device mismatch that arises as a result...    cs
# 23680   1001.1968v1  The need of sign language is increasing radica...    cs
# 37920   1111.2667v2  The graphical lasso (glasso) is a widely-used ...  stat
# 35259  cs/0207038v1  The axiom of recovery, while capturing a centr...    cs
# 7585   1802.04198v1  The workflow of data scientists normally invol...  stat
# ...             ...                                                ...   ...
# 21090  1707.07763v2  In recent work, we proved that the domain recu...    cs
# 37457  1707.04489v1  Freeway merging in congested traffic is a sign...    cs
# 5958    1401.2753v2  Uniform sampling of training data has been com...  stat
# 22462  1608.01398v3  A genome-wide association study (GWAS) correla...  stat
# 16260  1611.03279v1  From a diachronic corpus of Italian, we build ...    cs
#
#                                                    title  year  \
# 13817  A Trainable Neuromorphic Integrated Circuit th...  2015
# 23680  A Topological derivative based image segmentat...  2010
# 37920  A note on the lack of symmetry in the graphica...  2011
# 35259  Iterated revision and the axiom of recovery: a...  2002
# 7585   client2vec: Towards Systematic Baselines for B...  2018
# ...                                                  ...   ...
# 21090  Domain Recursion for Lifted Inference with Exi...  2017
# 37457  Freeway Merging in Congested Traffic based on ...  2017
# 5958    Stochastic Optimization with Importance Sampling  2014
# 22462  Iterative Hard Thresholding for Model Selectio...  2016
# 16260  Tracing metaphors in time through self-distanc...  2016
#
#                                                 keywords
# 13817  [mismatch, technology, submicron, degrades, ac...
# 23680  [language, increasing, radically, especially, ...
# 37920  [graphical, algorithm, estimating, covariance,...
# 35259  [recovery, capturing, intuition, regarding, co...
# 7585   [workflow, scientists, normally, involves, pot...
# ...                                                  ...
# 21090  [recursion, inference, inference, possible, re...
# 37457  [congested, significant, challenge, automated,...
# 5958   [sampling, training, commonly, traditional, st...
# 22462  [association, correlates, variation, variation...
# 16260  [diachronic, consecutive, similarity, differen...
#
# [4583 rows x 6 columns]

# %%
df['keywords']
# Out:
# 13817    [mismatch, technology, submicron, degrades, ac...
# 23680    [language, increasing, radically, especially, ...
# 37920    [graphical, algorithm, estimating, covariance,...
# 35259    [recovery, capturing, intuition, regarding, co...
# 7585     [workflow, scientists, normally, involves, pot...
#                                ...
# 38001    [introduce, learning, strategy, mojirsheibani,...
# 15743    [presents, approach, recurrent, regularization...
# 22326    [algorithms, impairment, specific, fundamental...
# 29478    [occluded, detection, challenging, detection, ...
# 21248    [temporally, abstract, specified, termination,...
# Name: keywords, Length: 5729, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 10813 words.
# Out of those 1119 have over 32 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3f2b2505-4638-4476-b70b-ed3be464838e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f2b2505-4638-4476-b70b-ed3be464838e")) {                    Plotly.newPlot(                        "3f2b2505-4638-4476-b70b-ed3be464838e",                        [{"x":["biological","regression","capability","inherent","statistical","measurement","resolution","projections","prototype","developed","accuracy","operating","variability","desirable","inspired","principles","population","additionally","integrated","exploits","learning","framework","increase","dimensional","technology","property","complexity","segmentation","measures","experiments","automated","training","improves","recognize","detection","achieving","combination","sequence","background","research","language","established","recognition","discrimination","contribute","especially","significantly","different","implementation","discrete","challenging","additional","increasing","automatically","proposes","approach","requires","community","demonstrate","estimates","estimate","possible","numerical","covariance","estimator","underlying","producing","estimating","produces","penalized","intermediate","multivariate","potentially","algorithm","procedures","regularized","optimization","available","possibly","identify","likelihood","graphical","regularization","negative","matrices","explicit","representation","particular","preferences","recovery","connection","capturing","interesting","properties","treatment","provides","semantic","conditions","captured","similarities","regarding","designing","experimental","engineering","applications","internal","optimized","selected","representations","involves","baselines","processes","algorithmic","selection","denoising","experience","behaviors","represent","autoencoders","embeddings","systematic","function","introduce","modelling","synthetic","allowing","extending","stationary","gaussian","extension","variable","comparable","component","structures","annotation","includes","annotations","relation","languages","technique","extracting","mixtures","practical","polynomial","solutions","challenge","formulate","elements","distribution","components","measurements","recommendation","matching","directly","estimated","distributions","typically","consistent","functions","motivated","obtained","construct","estimation","minimization","guarantees","statistically","techniques","existing","completion","alternating","spectral","exponential","leveraging","reconstruction","substantial","phenomena","computational","insights","resulting","hierarchical","competing","promising","approximation","stochastic","incorporating","achieved","operations","analysis","dramatically","attempts","bayesian","relevant","compared","conventional","policies","scenarios","environments","environment","important","improving"],"y":[39,104,46,34,136,23,102,24,23,158,388,21,27,36,87,29,39,57,48,37,1084,456,75,166,55,55,209,171,85,524,93,475,118,42,293,63,109,145,55,267,303,46,330,12,26,104,236,674,123,92,225,89,90,170,93,857,138,73,489,57,109,192,76,25,15,100,16,43,66,6,24,10,40,759,44,38,276,254,19,114,46,58,65,49,40,63,337,234,36,36,33,26,76,201,19,245,212,111,51,26,35,43,359,50,379,36,42,61,212,54,52,88,36,140,38,33,16,104,22,61,28,324,309,53,105,74,31,16,84,78,69,82,104,110,54,49,57,67,90,166,59,16,118,60,160,138,49,41,190,93,38,20,108,143,50,115,79,66,186,55,220,78,172,77,52,19,338,407,24,25,53,37,38,86,34,27,281,52,125,97,14,109,104,124,44,142,71,479,20,34,143,98,314,96,38,84,77,108,319,87],"type":"bar"},{"x":["biological","regression","capability","inherent","statistical","measurement","resolution","projections","prototype","developed","accuracy","operating","variability","desirable","inspi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (1119,), (1119, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7818499127399651

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3944954128440366);'>Transfer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Learning</span> <span style=''>for</span> <span style=''>Endoscopic</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3944954128440366);'>transfer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>learning</span> <span style=''>of</span> <span style=''>endoscopic</span> <span style=''>images</span> <span style=''>For</span> <span style=''>transferring</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>features</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>obtained</span> <span style=''>from</span> <span style=''>images</span> <span style=''>taken</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>(old</span> <span style=''>and</span> <span style=''>new)</span> <span style=''>endoscopes</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>Max</span> <span style=''>Margin</span> <span style=''>Domain</span> <span style='background-color:rgba(0, 255, 0, 0.3944954128440366);'>Transfer</span> <span style=''>(MMDT)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proposed</span> <span style=''>by</span> <span style=''>Hoffman</span> <span style=''>et</span> <span style=''>al</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>use</span> <span style=''>L2</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3838862559241707);'>regularization</span> <span style=''>called</span> <span style=''>Max</span> <span style=''>Margin</span> <span style=''>Domain</span> <span style='background-color:rgba(0, 255, 0, 0.3944954128440366);'>Transfer</span> <span style=''>with</span> <span style=''>L2</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constraints</span> <span style=''>(MMDTL2)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>the</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>cost</span> <span style='background-color:rgba(0, 255, 0, 0.3247232472324723);'>Experimental</span> <span style=''>results</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proposed</span> <span style=''>MMDTL2</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperforms</span> <span style=''>MMDT</span> <span style=''>for</span> <span style=''>real</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>taken</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>endoscopes</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Discovering</span> <span style=''>Latent</span> <span style=''>Network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structure</span> <span style=''>in</span> <span style=''>Point</span> <span style=''>Process</span> <span style=''>Data</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Networks</span> <span style=''>play</span> <span style=''>a</span> <span style=''>central</span> <span style=''>role</span> <span style=''>in</span> <span style=''>modern</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>enabling</span> <span style=''>us</span> <span style=''>to</span> <span style=''>reason</span> <span style=''>about</span> <span style=''>systems</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>studying</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style=''>their</span> <span style=''>parts</span> <span style=''>Most</span> <span style=''>often</span> <span style=''>in</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analysis</span> <span style=''>the</span> <span style=''>edges</span> <span style=''>are</span> <span style=''>given</span> <span style=''>However</span> <span style=''>in</span> <span style=''>many</span> <span style=''>systems</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>impossible</span> <span style=''>to</span> <span style=''>measure</span> <span style=''>the</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>directly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Examples</span> <span style=''>of</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>networks</span> <span style=''>include</span> <span style=''>economic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>linking</span> <span style=''>financial</span> <span style=''>instruments</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>patterns</span> <span style=''>of</span> <span style=''>reciprocity</span> <span style=''>in</span> <span style=''>gang</span> <span style=''>violence</span> <span style=''>In</span> <span style=''>these</span> <span style=''>cases</span> <span style=''>we</span> <span style=''>are</span> <span style=''>limited</span> <span style=''>to</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>of</span> <span style=''>events</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>each</span> <span style=''>node</span> <span style=''>To</span> <span style=''>enable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analysis</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implicit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>networks</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combines</span> <span style=''>mutually</span> <span style=''>exciting</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>with</span> <span style=''>random</span> <span style=''>graph</span> <span style=''>models</span> <span style=''>We</span> <span style=''>show</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Power</span> <span style=''>of</span> <span style=''>Asymmetry</span> <span style=''>in</span> <span style=''>Binary</span> <span style=''>Hashing</span> <br/><br/><span style=''>When</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>approximating</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarity</span> <span style=''>using</span> <span style=''>the</span> <span style=''>hamming</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distance</span> <span style=''>between</span> <span style=''>short</span> <span style=''>binary</span> <span style=''>hashes</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>even</span> <span style=''>if</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarity</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>symmetric</span> <span style=''>we</span> <span style=''>can</span> <span style=''>have</span> <span style=''>shorter</span> <span style=''>and</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accurate</span> <span style=''>hashes</span> <span style=''>by</span> <span style=''>using</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distinct</span> <span style=''>code</span> <span style=''>maps</span> <span style=''>Ie</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>approximating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarity</span> <span style=''>between</span> <span style=''>x</span> <span style=''>and</span> <span style=''>x</span> <span style=''>as</span> <span style=''>the</span> <span style=''>hamming</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distance</span> <span style=''>between</span> <span style=''>f(x)</span> <span style=''>and</span> <span style=''>g(x)</span> <span style=''>for</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distinct</span> <span style=''>binary</span> <span style=''>codes</span> <span style=''>fg</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>as</span> <span style=''>the</span> <span style=''>hamming</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distance</span> <span style=''>between</span> <span style=''>f(x)</span> <span style=''>and</span> <span style=''>f(x)</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Interpretable</span> <span style=''>Musical</span> <span style=''>Compositional</span> <span style=''>Rules</span> <span style=''>and</span> <span style=''>Traces</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Throughout</span> <span style=''>music</span> <span style=''>history</span> <span style=''>theorists</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identified</span> <span style=''>and</span> <span style=''>documented</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>rules</span> <span style=''>that</span> <span style=''>capture</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decisions</span> <span style=''>of</span> <span style=''>composers</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>asks</span> <span style=''>Can</span> <span style=''>a</span> <span style=''>machine</span> <span style=''>behave</span> <span style=''>like</span> <span style=''>a</span> <span style=''>music</span> <span style=''>theorist</span> <span style=''>It</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presents</span> <span style=''>MUS</span> <span style=''>ROVER</span> <span style=''>a</span> <span style=''>self</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learning</span> <span style=''>system</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovering</span> <span style=''>rules</span> <span style=''>from</span> <span style=''>symbolic</span> <span style=''>music</span> <span style=''>MUS</span> <span style=''>ROVER</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performs</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learning</span> <span style=''>via</span> <span style=''>n</span> <span style=''>gram</span> <span style=''>models</span> <span style=''>to</span> <span style=''>extract</span> <span style=''>compositional</span> <span style=''>rules</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>patterns</span> <span style=''>over</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>features</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluate</span> <span style=''>MUS</span> <span style=''>ROVER</span> <span style=''>on</span> <span style=''>Bachs</span> <span style=''>(SATB)</span> <span style=''>chorales</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrating</span> <span style=''>that</span> <span style=''>it</span> <span style=''>can</span> <span style=''>recover</span> <span style=''>known</span> <span style=''>rules</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identify</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characteristic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>patterns</span> <span style=''>for</span> <span style=''>further</span> <span style=''>study</span> <span style=''>We</span> <span style=''>discuss</span> <span style=''>how</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extracted</span> <span style=''>rules</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>in</span> <span style=''>both</span> <span style=''>machine</span> <span style=''>and</span> <span style=''>human</span> <span style=''>composition</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.14354258296681327)
# 	detection (0.1171531387445022)
# 	computer (0.09316273490603759)
# 	knowledge (0.13634546181527388)
# 	information (0.24470211915233905)
# 	semantic (0.08476609356257497)
# 	convolutional (0.12395041983206717)
# 	different (0.2694922031187525)
# 	recognition (0.13194722111155538)
# 	language (0.1211515393842463)
#
# Some Statistics words are:
# 	theoretical (0.15609990393852066)
# 	statistical (0.15609990393852066)
# 	estimation (0.17963496637848222)
# 	bayesian (0.17002881844380405)
# 	distribution (0.19020172910662825)
# 	dimensional (0.18539865513928913)
# 	inference (0.1935638808837656)
# 	gaussian (0.15994236311239193)
# 	learning (0.5619596541786743)
# 	regression (0.1724303554274736)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="95a9e251-0590-4824-845f-ce915a56736a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95a9e251-0590-4824-845f-ce915a56736a")) {                    Plotly.newPlot(                        "95a9e251-0590-4824-845f-ce915a56736a",                        [{"x":["biological","regression","capability","inherent","statistical","measurement","resolution","projections","prototype","developed","accuracy","operating","variability","desirable","inspired","principles","population","additionally","integrated","exploits","learning","framework","increase","dimensional","technology","property","complexity","segmentation","measures","experiments","automated","training","improves","recognize","detection","achieving","combination","sequence","background","research","language","established","recognition","discrimination","contribute","especially","significantly","different","implementation","discrete","challenging","additional","increasing","automatically","proposes","approach","requires","community","demonstrate","estimates","estimate","possible","numerical","covariance","estimator","underlying","producing","estimating","produces","penalized","intermediate","multivariate","potentially","algorithm","procedures","regularized","optimization","available","possibly","identify","likelihood","graphical","regularization","negative","matrices","explicit","representation","particular","preferences","recovery","connection","capturing","interesting","properties","treatment","provides","semantic","conditions","captured","similarities","regarding","designing","experimental","engineering","applications","internal","optimized","selected","representations","involves","baselines","processes","algorithmic","selection","denoising","experience","behaviors","represent","autoencoders","embeddings","systematic","function","introduce","modelling","synthetic","allowing","extending","stationary","gaussian","extension","variable","comparable","component","structures","annotation","includes","annotations","relation","languages","technique","extracting","mixtures","practical","polynomial","solutions","challenge","formulate","elements","distribution","components","measurements","recommendation","matching","directly","estimated","distributions","typically","consistent","functions","motivated","obtained","construct","estimation","minimization","guarantees","statistically","techniques","existing","completion","alternating","spectral","exponential","leveraging","reconstruction","substantial","phenomena","computational","insights","resulting","hierarchical","competing","promising","approximation","stochastic","incorporating","achieved","operations","analysis","dramatically","attempts","bayesian","relevant","compared","conventional","policies","scenarios","environments","environment","important","improving","observed","reinforcement","adaptation","outperforms","transfer","algorithms","interest","empirically","performing","required","networks","detecting","strategy","concerns","robustness","problems","ensemble","attractive","recently","classifying","classification","adversarial","perturbations","probabilistic","observational","behavior","inferring","considerable","evaluate","direction","explored","inference","relationships","accurate","performs","inferred","identifying","association","patients","characteristics","transition","contrast","efficient","probability","successfully","quantitative","features","efficiency","validity","selecting","predictions","powerful","assumption","machines","provably","suitable","parameters","reliability","including","generated","confidence","remaining","independently","traditional","advances","information","prediction","describes","sentences","impro ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
#
# Some words which never appear in Statistics papers:

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 0.0005013902183326496

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.774869109947644
